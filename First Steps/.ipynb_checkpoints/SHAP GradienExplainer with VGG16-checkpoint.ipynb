# %%
#Source: https://github.com/slundberg/shap

from keras.applications.vgg16 import VGG16
from keras.applications.vgg16 import preprocess_input
import keras.backend as K
import numpy as np
import json
import shap
import random
import opencv

import tensorflow.compat.v1.keras.backend as Kf
import tensorflow as tf
tf.compat.v1.disable_eager_execution()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [46], in <cell line: 10>()
#       8 import shap
#       9 import random
# ---> 10 import opencv
#      12 import tensorflow.compat.v1.keras.backend as Kf
#      13 import tensorflow as tf
#
# ModuleNotFoundError: No module named 'opencv'

# %%
random_pics = random.sample(range(0, 50), 5)

# %%
# load pre-trained model and choose five images to explain
model = VGG16(weights='imagenet', include_top=True)
X,y = shap.datasets.imagenet50()
to_explain = X[[random_pics]]
# Out:
# 2022-05-20 19:23:39.915632: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-05-20 19:23:39.973861: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-05-20 19:23:40.247758: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.

# %%
# load the ImageNet class names
url = "https://s3.amazonaws.com/deep-learning-models/image-models/imagenet_class_index.json"
fname = shap.datasets.cache(url)
with open(fname) as f:
    class_names = json.load(f)

# %%
#run Gradient Explainer on Model
explainer = shap.GradientExplainer(model, preprocess_input(X.copy()))
shap_values,indexes = explainer.shap_values(to_explain, ranked_outputs=1)
# Out:
# WARNING:tensorflow:From /Users/tobiaslabarta/miniforge3/envs/mlp/lib/python3.8/site-packages/shap/explainers/tf_utils.py:28: The name tf.keras.backend.get_session is deprecated. Please use tf.compat.v1.keras.backend.get_session instead.
# 2022-05-20 19:07:42.251784: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-05-20 19:07:42.600688: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-05-20 19:07:51.436937: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-05-20 19:07:59.865345: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-05-20 19:08:08.246656: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-05-20 19:08:16.548521: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.

# %%
masker = shap.maskers.Image("inpaint_telea", X[0].shape)

explainer = shap.Explainer(model, masker, output_names=class_names)

shap_values = explainer(X[1:3], max_evals=500, batch_size=50, outputs=shap.Explanation.argsort.flip[:1])
shap.image_plot(shap_values)
# Out:
# cv2 could not be imported!
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [44], in <cell line: 1>()
# ----> 1 masker = shap.maskers.Image("inpaint_telea", X[0].shape)
#       3 explainer = shap.Explainer(model, masker, output_names=class_names)
#       5 shap_values = explainer(X[1:3], max_evals=500, batch_size=50, outputs=shap.Explanation.argsort.flip[:1])
#
# File ~/miniforge3/envs/mlp/lib/python3.8/site-packages/shap/maskers/_image.py:48, in Image.__init__(self, mask_value, shape)
#      46     self.mask_value = mask_value.flatten()
#      47 elif isinstance(mask_value, str):
# ---> 48     assert_import("cv2")
#      49     self.mask_value = mask_value
#      50     if mask_value.startswith("blur("):
#
# File ~/miniforge3/envs/mlp/lib/python3.8/site-packages/shap/utils/_general.py:25, in assert_import(package_name)
#      23 msg,e = import_errors[package_name]
#      24 print(msg)
# ---> 25 raise e
#
#     [... skipping hidden 1 frame]
#
# Input In [44], in <cell line: 1>()
# ----> 1 masker = shap.maskers.Image("inpaint_telea", X[0].shape)
#       3 explainer = shap.Explainer(model, masker, output_names=class_names)
#       5 shap_values = explainer(X[1:3], max_evals=500, batch_size=50, outputs=shap.Explanation.argsort.flip[:1])
#
# File ~/miniforge3/envs/mlp/lib/python3.8/site-packages/shap/maskers/_image.py:48, in Image.__init__(self, mask_value, shape)
#      46     self.mask_value = mask_value.flatten()
#      47 elif isinstance(mask_value, str):
# ---> 48     assert_import("cv2")
#      49     self.mask_value = mask_value
#      50     if mask_value.startswith("blur("):
#
# File ~/miniforge3/envs/mlp/lib/python3.8/site-packages/shap/utils/_general.py:25, in assert_import(package_name)
#      23 msg,e = import_errors[package_name]
#      24 print(msg)
# ---> 25 raise e
#
#     [... skipping similar frames: <cell line: 1> at line 1 (1 times), Image.__init__ at line 48 (1 times), assert_import at line 25 (1 times), InteractiveShell.run_code at line 3397 (1 times)]
#
#     [... skipping hidden 1 frame]
#
# Input In [44], in <cell line: 1>()
# ----> 1 masker = shap.maskers.Image("inpaint_telea", X[0].shape)
#       3 explainer = shap.Explainer(model, masker, output_names=class_names)
#       5 shap_values = explainer(X[1:3], max_evals=500, batch_size=50, outputs=shap.Explanation.argsort.flip[:1])
#
# File ~/miniforge3/envs/mlp/lib/python3.8/site-packages/shap/maskers/_image.py:48, in Image.__init__(self, mask_value, shape)
#      46     self.mask_value = mask_value.flatten()
#      47 elif isinstance(mask_value, str):
# ---> 48     assert_import("cv2")
#      49     self.mask_value = mask_value
#      50     if mask_value.startswith("blur("):
#
# File ~/miniforge3/envs/mlp/lib/python3.8/site-packages/shap/utils/_general.py:25, in assert_import(package_name)
#      23 msg,e = import_errors[package_name]
#      24 print(msg)
# ---> 25 raise e
#
# File ~/miniforge3/envs/mlp/lib/python3.8/site-packages/shap/maskers/_image.py:8, in <module>
#       5 from .._serializable import Serializer, Deserializer
#       7 try:
# ----> 8     import cv2
#       9 except ImportError as e:
#      10     record_import_error("cv2", "cv2 could not be imported!", e)
#
# ModuleNotFoundError: No module named 'cv2'

# %%
# get the names for the classes
index_names = np.vectorize(lambda x: class_names[str(x)][1])(indexes)

# %%
# plot the explanations
shap.image_plot(shap_values, to_explain, index_names)
