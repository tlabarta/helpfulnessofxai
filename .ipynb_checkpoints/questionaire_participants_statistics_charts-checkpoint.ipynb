# %%
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Bad key "text.kerning_factor" on line 4 in
# /Users/julianvonklitzing/opt/anaconda3/envs/xai_env/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.1.3/matplotlibrc.template
# or from the matplotlib source distribution

# %% [markdown]
# # Load data

# %%
DATA_PATH = "data2/data_tu-helpfulness-of-xai_2022-06-29_10-48.xlsx"
DATA_PREPARED_PATH = f"{DATA_PATH.split('.')[0]}_PREPARED.{DATA_PATH.split('.')[1]}"
df = pd.read_excel(DATA_PATH)
df_prepared = pd.read_excel(DATA_PREPARED_PATH)

# %% [markdown]
# # Demographic questions: Create charts (visual overview)

# %%
df_prepared = df_prepared.drop_duplicates(subset=["case"]).reset_index(drop=True)

# %%
df_prepared
# Out:
#      Unnamed: 0  case      Education Education: Other          ML Experience  \
# 0             0   579     Highschool              NaN             Not at all
# 1           456   581       Graduate              NaN  Between 3 and 5 years
# 2           715   587     Highschool              NaN             Not at all
# 3          1064   589       Graduate              NaN           Under 1 year
# 4          1496   605     Highschool              NaN             Not at all
# ..          ...   ...            ...              ...                    ...
# 131         199  1626  Undergraduate              NaN           Under 1 year
# 132        2743  1654     Highschool              NaN             Not at all
# 133        1724  1656  Undergraduate              NaN           Under 1 year
# 134        3253  1658       Graduate              NaN           Under 1 year
# 135        2051  1660   Postgraduate              NaN  Between 1 and 3 years
#
#        XAI Experience Color Blindness Color Blindness: Yes  \
# 0                 NaN              No                  NaN
# 1        Very helpful              No                  NaN
# 2                 NaN              No                  NaN
# 3    Somewhat helpful              No                  NaN
# 4                 NaN              No                  NaN
# ..                ...             ...                  ...
# 131  Somewhat helpful              No                  NaN
# 132               NaN              No                  NaN
# 133  Somewhat helpful              No                  NaN
# 134  Somewhat helpful              No                  NaN
# 135  Somewhat helpful              No                  NaN
#
#     Visual Impairment Affect Feedback Form: [01] question_code  response  \
# 0                        NaN                 NaN          B715     False
# 1                        NaN                 NaN          C323      True
# 2                        NaN                 NaN          C222      True
# 3                        NaN                 NaN          B204      True
# 4                        NaN                 NaN          B302      True
# ..                       ...                 ...           ...       ...
# 131                      NaN                 NaN          B704     False
# 132                      NaN                 NaN          B517      True
# 133                      NaN                 NaN          B107     False
# 134                      NaN                 NaN          B603      True
# 135                      NaN                 NaN          B815      True
#
#                label  img_idx model               method  is_pred_correct
# 0         chiffonier     4389  alex                 SHAP             True
# 1    cassette_player     4266   vgg                 SHAP            False
# 2          spotlight     7995   vgg                 SHAP            False
# 3         coral_reef     9710  alex                 SHAP             True
# 4         coral_reef     9710  alex                 LIME             True
# ..               ...      ...   ...                  ...              ...
# 131      Boston_bull     1073  alex                 SHAP            False
# 132         bookcase     3944  alex                  LRP            False
# 133    shopping_cart     7692   vgg  IntegratedGradients             True
# 134        boathouse     3898  alex  IntegratedGradients            False
# 135           buckle     4066  alex  IntegratedGradients            False
#
# [136 rows x 17 columns]

# %%
def func(pct):
    return "{:1.1f}%".format(pct)

# %%
def my_fmt(x):
    print(x)
    return '{:.4f}%\n({:.0f})'.format(x, total*x/100)

# %%
def plot_statistics():
    fig, ax = plt.subplots(3, 2, figsize=(20, 30))
    ax[0][0].pie(autopct=lambda pct: func(pct), labels=df_prepared["Education"].value_counts(dropna=False, normalize=True).index, x=df_prepared["Education"].value_counts(dropna=False, normalize=False), textprops={"size": 18})
    ax[0][0].set_title("Education", size= 25)
    
    ax[0][1].pie(autopct=lambda pct: func(pct), labels=df_prepared["ML Experience"].value_counts(dropna=False, normalize=True).index, x=df_prepared["ML Experience"].value_counts(dropna=False, normalize=False), textprops={"size": 18})
    ax[0][1].set_title("ML Experience", size= 25)
    
    ax[1][0].pie(autopct=lambda pct: func(pct), labels=df_prepared["XAI Experience"].value_counts(dropna=True, normalize=True).index, x=df_prepared["XAI Experience"].value_counts(dropna=True, normalize=False), textprops={"size": 18})
    ax[1][0].set_title("XAI Experience (Excluding NaN)", size= 25)
    
    ax[1][1].pie(autopct=lambda pct: func(pct), labels=df_prepared["Color Blindness"].value_counts(dropna=False, normalize=True).index, x=df_prepared["Color Blindness"].value_counts(dropna=False, normalize=False), textprops={"size": 18})
    ax[1][1].set_title("Color Blindness", size= 25)
    
    ax[2][0].pie(autopct=lambda pct: func(pct), labels=df_prepared["Visual Impairment Affect"].value_counts(dropna=True, normalize=True).index, x=df_prepared["Visual Impairment Affect"].value_counts(dropna=True, normalize=False), textprops={"size": 18})
    ax[2][0].set_title("Visual Impairment Affect (Excluding NaN)", size= 25)
    
    fig.suptitle(f"Statistics calculated on a total of {df_prepared.shape[0]} participant", size=35)

# %%
plot_statistics()

# %% [markdown]
# # Time taken to finish survey

# %%
df_column_descriptions = df.loc[0]

# %%
df = df.drop(0)

# %%
# set dtypes for TIME columns from object to integer
df = df.astype(dict(zip(df.columns[df.columns.get_loc("TIME001"):df.columns.get_loc("TIME001")+6], [int]*6)))

# %%
# guess time is meassured in seconds
df.iloc[:, df.columns.get_loc("TIME001"):df.columns.get_loc("TIME001")+6].boxplot(showfliers=False)

# %%
df.iloc[:, df.columns.get_loc("TIME001"):df.columns.get_loc("TIME001")+6].describe()
# Out:
#             TIME001      TIME002      TIME003     TIME004     TIME005  \
# count    136.000000   136.000000   136.000000  136.000000  136.000000
# mean     326.602941   165.551471   266.705882   29.882353   24.529412
# std     1957.199069   502.676139   243.062197   37.107463   49.796020
# min        2.000000     4.000000    57.000000    9.000000    1.000000
# 25%        6.000000    45.000000   148.750000   16.000000    4.000000
# 50%       16.000000   102.500000   210.000000   20.000000   10.000000
# 75%       55.750000   171.000000   274.500000   30.250000   18.250000
# max    18674.000000  5850.000000  2216.000000  382.000000  320.000000
#
#           TIME_SUM
# count   136.000000
# mean    332.088235
# std     212.649650
# min       0.000000
# 25%     188.500000
# 50%     337.500000
# 75%     481.750000
# max    1101.000000
