# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from methods import data_handler
from tqdm import tqdm

from torchvision import datasets
import os
from itertools import chain

# %%
questionnaires = data_handler.get_questionaires("data2/questionaires_shuffled.pickle")
labels = data_handler.get_labels()
# Out:
# Using downloaded and verified file: ./data/imagenet_class_index.json

# %%
def get_label_from_img_idx(img_idx, testset_path, labels):    
    img_folder = datasets.ImageFolder(root=testset_path)
    img_path = img_folder.imgs[img_idx][0]
    img_name = img_path.split(os.sep)[-1]
    # extract correct class
    class_idx_true_str = img_path.split(os.sep)[-2]
    img_label_true = labels[class_idx_true_str][1]
    return img_label_true

# %%
questionnaires_2 = []
for questionnaire in tqdm(questionnaires):
    questionnaire_2 = []
    for question in questionnaire:
        label = get_label_from_img_idx(question[0], "data2/imagenetv2-matched-frequency-format-val", labels)
        question_labled = (label, ) + question[1:]        
        questionnaire_2.append(question_labled)
    questionnaires_2.append(questionnaire_2)
# Out:
# 100%|███████████████████████████████████████████| 12/12 [00:35<00:00,  2.96s/it]

# %%
df = pd.read_excel("data2/data_tu-helpfulness-of-xai_2022-06-21_17-15.xlsx")

# %%
qn = 1
for idx, qu in enumerate(questionnaires_2[qn]):
    print(df[df.columns[6 + qn*24:6 + qn*24 + 24]].iloc[0][idx], "\t", qu[0])
# Out:
# q10water tower 	 water_tower
# q6boathouse 	 boathouse
# q21printer 	 printer
# q17hummingbird 	 hummingbird
# q12jaguar 	 jaguar
# q18flagpole 	 flagpole
# q3gyromitra 	 gyromitra
# q13football helmet 	 football_helmet
# q19barrel 	 barrel
# q23purse 	 purse
# q8slide rule 	 slide_rule
# q20bolo tie 	 bolo_tie
# q7goose 	 goose
# q9Boston bull 	 Boston_bull
# q5custard apple 	 custard_apple
# q4coral reef 	 coral_reef
# q15drumstick 	 drumstick
# q1shopping cart 	 shopping_cart
# q22malamute 	 malamute
# q24clumber 	 clumber
# q2matchstick 	 matchstick
# q11chambered nautilus 	 chambered_nautilus
# q16basenji 	 basenji
# q14red-breasted merganser 	 red-breasted_merganser

# %%
"""
0: passt nicht
1: passt
2-7: passt nicht
8:passt
9-11: passt nicht

Warum passen 1 und 8??
"""

# %% [markdown]
# ## Load mapping

# %%
codes_list = []
for i in range(1, 12+1):
    codes = pd.read_csv(f"questionaires_shuffle_order/questionaire_{i}.txt", sep=";", names=[0, 1])[1]
    codes = codes.str.extract("(\w\d{3})")
    codes = list(codes[0])
    df[codes]
    codes_list.append(codes)

# %%
list(chain(*questionnaires))
# Out:
# [(9521, 'vgg', 'LRP', True),
#  (1073, 'vgg', 'SHAP', True),
#  (9992, 'alex', 'IntegratedGradients', False),
#  (5253, 'vgg', 'ConfidenceScores', False),
#  (5976, 'vgg', 'IntegratedGradients', False),
#  (2187, 'alex', 'ConfidenceScores', True),
#  (329, 'alex', 'LIME', True),
#  (9899, 'alex', 'IntegratedGradients', True),
#  (2136, 'alex', 'LIME', False),
#  (9732, 'vgg', 'SHAP', False),
#  (5789, 'alex', 'LRP', False),
#  (6063, 'alex', 'ConfidenceScores', False),
#  (7489, 'vgg', 'LRP', False),
#  (9663, 'alex', 'SHAP', False),
#  (8917, 'alex', 'SHAP', True),
#  (215, 'vgg', 'ConfidenceScores', True),
#  (9931, 'vgg', 'LIME', True),
#  (7769, 'vgg', 'gradCAM', True),
#  (9710, 'alex', 'LRP', True),
#  (350, 'vgg', 'LIME', False),
#  (995, 'vgg', 'gradCAM', False),
#  (5452, 'alex', 'gradCAM', True),
#  (3898, 'alex', 'gradCAM', False),
#  (7692, 'vgg', 'IntegratedGradients', True),
#  (8917, 'alex', 'LIME', True),
#  (3898, 'alex', 'LRP', False),
#  (7152, 'vgg', 'ConfidenceScores', False),
#  (9349, 'alex', 'ConfidenceScores', True),
#  (2136, 'alex', 'ConfidenceScores', False),
#  (5091, 'vgg', 'SHAP', False),
#  (9931, 'vgg', 'ConfidenceScores', True),
#  (5132, 'alex', 'SHAP', False),
#  (3655, 'vgg', 'LIME', False),
#  (7210, 'vgg', 'IntegratedGradients', False),
#  (7769, 'vgg', 'LRP', True),
#  (3921, 'alex', 'LRP', True),
#  (9899, 'vgg', 'gradCAM', True),
#  (1073, 'vgg', 'LIME', True),
#  (9521, 'vgg', 'SHAP', True),
#  (9710, 'alex', 'SHAP', True),
#  (4931, 'alex', 'gradCAM', False),
#  (7692, 'alex', 'gradCAM', True),
#  (1674, 'vgg', 'gradCAM', False),
#  (1315, 'vgg', 'LRP', False),
#  (6063, 'alex', 'IntegratedGradients', False),
#  (215, 'vgg', 'IntegratedGradients', True),
#  (1724, 'alex', 'LIME', False),
#  (9784, 'alex', 'IntegratedGradients', True),
#  (3584, 'alex', 'gradCAM', False),
#  (7692, 'alex', 'LRP', True),
#  (9521, 'vgg', 'LIME', True),
#  (9703, 'alex', 'SHAP', True),
#  (1408, 'vgg', 'LRP', False),
#  (6935, 'vgg', 'gradCAM', True),
#  (215, 'alex', 'gradCAM', True),
#  (8917, 'alex', 'ConfidenceScores', True),
#  (9710, 'alex', 'LIME', True),
#  (6063, 'vgg', 'gradCAM', False),
#  (2136, 'alex', 'IntegratedGradients', False),
#  (5186, 'alex', 'IntegratedGradients', True),
#  (4451, 'alex', 'ConfidenceScores', False),
#  (9931, 'vgg', 'IntegratedGradients', True),
#  (1990, 'alex', 'LIME', False),
#  (4584, 'vgg', 'LIME', False),
#  (9360, 'vgg', 'ConfidenceScores', False),
#  (7769, 'vgg', 'SHAP', True),
#  (4780, 'vgg', 'IntegratedGradients', False),
#  (9899, 'vgg', 'LRP', True),
#  (8713, 'alex', 'LRP', False),
#  (3898, 'alex', 'SHAP', False),
#  (1073, 'vgg', 'ConfidenceScores', True),
#  (5705, 'vgg', 'SHAP', False),
#  (3898, 'alex', 'LIME', False),
#  (7769, 'vgg', 'LIME', True),
#  (9899, 'vgg', 'SHAP', True),
#  (580, 'vgg', 'gradCAM', False),
#  (9710, 'alex', 'ConfidenceScores', True),
#  (6063, 'vgg', 'LRP', False),
#  (3747, 'vgg', 'ConfidenceScores', False),
#  (4031, 'vgg', 'IntegratedGradients', False),
#  (8406, 'alex', 'gradCAM', False),
#  (3657, 'alex', 'ConfidenceScores', False),
#  (76, 'vgg', 'LRP', True),
#  (9931, 'alex', 'gradCAM', True),
#  (7527, 'alex', 'IntegratedGradients', False),
#  (7692, 'alex', 'SHAP', True),
#  (2136, 'vgg', 'gradCAM', True),
#  (2569, 'alex', 'LIME', True),
#  (215, 'alex', 'LRP', True),
#  (8964, 'vgg', 'LIME', False),
#  (586, 'alex', 'SHAP', False),
#  (9208, 'alex', 'LRP', False),
#  (9521, 'vgg', 'ConfidenceScores', True),
#  (9707, 'vgg', 'SHAP', False),
#  (1073, 'vgg', 'IntegratedGradients', True),
#  (8917, 'alex', 'IntegratedGradients', True),
#  (2073, 'vgg', 'SHAP', True),
#  (8662, 'alex', 'SHAP', False),
#  (9899, 'vgg', 'LIME', True),
#  (1073, 'alex', 'gradCAM', False),
#  (3944, 'alex', 'LRP', False),
#  (8301, 'alex', 'ConfidenceScores', True),
#  (3959, 'vgg', 'LRP', False),
#  (217, 'alex', 'gradCAM', True),
#  (215, 'alex', 'SHAP', True),
#  (7769, 'vgg', 'ConfidenceScores', True),
#  (1876, 'vgg', 'LIME', False),
#  (880, 'vgg', 'gradCAM', False),
#  (2021, 'vgg', 'IntegratedGradients', False),
#  (7878, 'vgg', 'ConfidenceScores', False),
#  (8917, 'vgg', 'gradCAM', True),
#  (1995, 'alex', 'LIME', False),
#  (9521, 'vgg', 'IntegratedGradients', True),
#  (3898, 'alex', 'ConfidenceScores', False),
#  (7089, 'alex', 'IntegratedGradients', False),
#  (6063, 'vgg', 'SHAP', False),
#  (2136, 'vgg', 'LRP', True),
#  (7692, 'alex', 'LIME', True),
#  (9931, 'alex', 'LRP', True),
#  (9710, 'alex', 'IntegratedGradients', True),
#  (8917, 'vgg', 'LRP', True),
#  (1073, 'alex', 'LRP', False),
#  (9899, 'vgg', 'ConfidenceScores', True),
#  (826, 'vgg', 'LIME', True),
#  (7818, 'alex', 'LIME', False),
#  (8056, 'alex', 'LRP', True),
#  (7988, 'vgg', 'ConfidenceScores', False),
#  (765, 'alex', 'SHAP', False),
#  (2136, 'vgg', 'SHAP', True),
#  (215, 'alex', 'LIME', True),
#  (9931, 'alex', 'SHAP', True),
#  (9710, 'vgg', 'gradCAM', True),
#  (5233, 'vgg', 'IntegratedGradients', False),
#  (8528, 'vgg', 'gradCAM', False),
#  (7769, 'vgg', 'IntegratedGradients', True),
#  (2126, 'alex', 'IntegratedGradients', True),
#  (7692, 'alex', 'ConfidenceScores', True),
#  (910, 'alex', 'ConfidenceScores', False),
#  (4442, 'alex', 'gradCAM', False),
#  (5822, 'vgg', 'SHAP', False),
#  (9521, 'alex', 'gradCAM', True),
#  (3898, 'alex', 'IntegratedGradients', False),
#  (6063, 'vgg', 'LIME', False),
#  (5212, 'vgg', 'LRP', False),
#  (5450, 'alex', 'IntegratedGradients', False),
#  (712, 'vgg', 'LRP', False),
#  (1073, 'alex', 'SHAP', False),
#  (6303, 'alex', 'LRP', False),
#  (5037, 'alex', 'LIME', False),
#  (885, 'vgg', 'SHAP', False),
#  (2136, 'vgg', 'LIME', True),
#  (7769, 'alex', 'gradCAM', True),
#  (4389, 'alex', 'SHAP', True),
#  (9899, 'vgg', 'IntegratedGradients', True),
#  (8917, 'vgg', 'SHAP', True),
#  (9389, 'vgg', 'gradCAM', True),
#  (9710, 'vgg', 'LRP', True),
#  (6453, 'alex', 'gradCAM', False),
#  (9521, 'alex', 'LRP', True),
#  (2055, 'vgg', 'ConfidenceScores', True),
#  (9931, 'alex', 'LIME', True),
#  (215, 'alex', 'ConfidenceScores', True),
#  (8971, 'vgg', 'LIME', False),
#  (8224, 'vgg', 'IntegratedGradients', False),
#  (9200, 'alex', 'ConfidenceScores', False),
#  (6063, 'vgg', 'ConfidenceScores', False),
#  (3898, 'vgg', 'gradCAM', False),
#  (7692, 'alex', 'IntegratedGradients', True),
#  (6970, 'alex', 'SHAP', False),
#  (467, 'vgg', 'LRP', True),
#  (2050, 'vgg', 'SHAP', False),
#  (9931, 'alex', 'ConfidenceScores', True),
#  (1073, 'alex', 'LIME', False),
#  (9899, 'alex', 'gradCAM', True),
#  (7639, 'alex', 'LIME', True),
#  (7061, 'vgg', 'LIME', False),
#  (7702, 'vgg', 'gradCAM', False),
#  (3898, 'vgg', 'LRP', False),
#  (2136, 'vgg', 'ConfidenceScores', True),
#  (9710, 'vgg', 'SHAP', True),
#  (7769, 'alex', 'LRP', True),
#  (7044, 'alex', 'gradCAM', False),
#  (4066, 'alex', 'IntegratedGradients', False),
#  (6063, 'vgg', 'IntegratedGradients', False),
#  (8885, 'alex', 'LRP', False),
#  (8917, 'vgg', 'LIME', True),
#  (215, 'alex', 'IntegratedGradients', True),
#  (9521, 'alex', 'SHAP', True),
#  (7692, 'vgg', 'gradCAM', True),
#  (8830, 'vgg', 'ConfidenceScores', False),
#  (6210, 'vgg', 'IntegratedGradients', True),
#  (9788, 'alex', 'ConfidenceScores', False),
#  (9521, 'alex', 'LIME', True),
#  (738, 'alex', 'SHAP', False),
#  (7692, 'vgg', 'LRP', True),
#  (215, 'vgg', 'gradCAM', True),
#  (9899, 'alex', 'LRP', True),
#  (1482, 'vgg', 'ConfidenceScores', False),
#  (7769, 'alex', 'SHAP', True),
#  (7862, 'alex', 'ConfidenceScores', True),
#  (8917, 'vgg', 'ConfidenceScores', True),
#  (1780, 'vgg', 'LRP', False),
#  (2136, 'vgg', 'IntegratedGradients', True),
#  (9763, 'alex', 'IntegratedGradients', False),
#  (3917, 'alex', 'gradCAM', True),
#  (9931, 'alex', 'IntegratedGradients', True),
#  (1073, 'alex', 'ConfidenceScores', False),
#  (1530, 'alex', 'LIME', False),
#  (3898, 'vgg', 'SHAP', False),
#  (9626, 'vgg', 'LIME', False),
#  (9710, 'vgg', 'LIME', True),
#  (8794, 'vgg', 'IntegratedGradients', False),
#  (6243, 'vgg', 'SHAP', True),
#  (6063, 'alex', 'gradCAM', False),
#  (9372, 'vgg', 'gradCAM', False),
#  (5675, 'alex', 'LRP', False),
#  (5833, 'vgg', 'gradCAM', False),
#  (1073, 'alex', 'IntegratedGradients', False),
#  (6063, 'alex', 'LRP', False),
#  (9983, 'vgg', 'LIME', True),
#  (9383, 'alex', 'ConfidenceScores', False),
#  (7769, 'alex', 'LIME', True),
#  (215, 'vgg', 'LRP', True),
#  (9201, 'alex', 'IntegratedGradients', True),
#  (2136, 'alex', 'gradCAM', False),
#  (4211, 'vgg', 'LRP', False),
#  (7550, 'alex', 'gradCAM', True),
#  (9710, 'vgg', 'ConfidenceScores', True),
#  (2608, 'vgg', 'IntegratedGradients', False),
#  (9148, 'alex', 'LIME', False),
#  (9899, 'alex', 'SHAP', True),
#  (9521, 'alex', 'ConfidenceScores', True),
#  (8327, 'vgg', 'ConfidenceScores', False),
#  (9931, 'vgg', 'gradCAM', True),
#  (7692, 'vgg', 'SHAP', True),
#  (2995, 'alex', 'LRP', True),
#  (8917, 'vgg', 'IntegratedGradients', True),
#  (1292, 'alex', 'SHAP', False),
#  (6909, 'vgg', 'SHAP', False),
#  (3898, 'vgg', 'LIME', False),
#  (7995, 'vgg', 'SHAP', False),
#  (1073, 'vgg', 'gradCAM', True),
#  (9521, 'alex', 'IntegratedGradients', True),
#  (9899, 'alex', 'LIME', True),
#  (3106, 'vgg', 'ConfidenceScores', True),
#  (9710, 'vgg', 'IntegratedGradients', True),
#  (7769, 'alex', 'ConfidenceScores', True),
#  (3898, 'vgg', 'ConfidenceScores', False),
#  (2451, 'alex', 'IntegratedGradients', False),
#  (2495, 'alex', 'LRP', True),
#  (9753, 'vgg', 'LRP', False),
#  (8054, 'alex', 'SHAP', True),
#  (9931, 'vgg', 'LRP', True),
#  (9509, 'vgg', 'gradCAM', False),
#  (7692, 'vgg', 'LIME', True),
#  (8917, 'alex', 'gradCAM', True),
#  (1602, 'alex', 'gradCAM', False),
#  (2136, 'alex', 'LRP', False),
#  (6063, 'alex', 'SHAP', False),
#  (9777, 'alex', 'LIME', False),
#  (3873, 'alex', 'ConfidenceScores', False),
#  (5123, 'vgg', 'IntegratedGradients', False),
#  (215, 'vgg', 'SHAP', True),
#  (3988, 'vgg', 'LIME', False),
#  (7769, 'alex', 'IntegratedGradients', True),
#  (6063, 'alex', 'LIME', False),
#  (8917, 'alex', 'LRP', True),
#  (1073, 'vgg', 'LRP', True),
#  (2136, 'alex', 'SHAP', False),
#  (215, 'vgg', 'LIME', True),
#  (3898, 'vgg', 'IntegratedGradients', False),
#  (1159, 'vgg', 'LIME', False),
#  (6675, 'vgg', 'IntegratedGradients', True),
#  (8052, 'alex', 'IntegratedGradients', False),
#  (4248, 'vgg', 'LRP', False),
#  (7692, 'vgg', 'ConfidenceScores', True),
#  (4323, 'vgg', 'ConfidenceScores', False),
#  (9899, 'alex', 'ConfidenceScores', True),
#  (4266, 'vgg', 'SHAP', False),
#  (8002, 'alex', 'LIME', True),
#  (6979, 'alex', 'gradCAM', False),
#  (9931, 'vgg', 'SHAP', True),
#  (753, 'vgg', 'gradCAM', False),
#  (9521, 'vgg', 'gradCAM', True),
#  (9710, 'alex', 'gradCAM', True),
#  (7798, 'alex', 'LRP', False),
#  (8034, 'alex', 'SHAP', True),
#  (7808, 'alex', 'ConfidenceScores', False)]

# %%
list(chain(*codes_list))
# Out:
# ['B108',
#  'B111',
#  'B118',
#  'B123',
#  'B124',
#  'B115',
#  'B113',
#  'B104',
#  'B110',
#  'B122',
#  'B117',
#  'B112',
#  'B121',
#  'B114',
#  'B103',
#  'B105',
#  'B109',
#  'B106',
#  'B101',
#  'B120',
#  'B119',
#  'B116',
#  'B102',
#  'B107',
#  'B210',
#  'B206',
#  'B221',
#  'B217',
#  'B212',
#  'B218',
#  'B203',
#  'B213',
#  'B219',
#  'B223',
#  'B208',
#  'B220',
#  'B207',
#  'B209',
#  'B205',
#  'B204',
#  'B215',
#  'B201',
#  'B222',
#  'B224',
#  'B202',
#  'B211',
#  'B216',
#  'B214',
#  'B313',
#  'B310',
#  'B309',
#  'B320',
#  'B319',
#  'B321',
#  'B303',
#  'B301',
#  'B302',
#  'B312',
#  'B306',
#  'B317',
#  'B314',
#  'B304',
#  'B315',
#  'B318',
#  'B324',
#  'B308',
#  'B323',
#  'B307',
#  'B316',
#  'B311',
#  'B305',
#  'B322',
#  'B411',
#  'B404',
#  'B406',
#  'B424',
#  'B412',
#  'B402',
#  'B421',
#  'B423',
#  'B416',
#  'B418',
#  'B415',
#  'B407',
#  'B419',
#  'B403',
#  'B408',
#  'B414',
#  'B401',
#  'B420',
#  'B413',
#  'B417',
#  'B409',
#  'B422',
#  'B405',
#  'B410',
#  'B521',
#  'B518',
#  'B511',
#  'B510',
#  'B517',
#  'B516',
#  'B524',
#  'B514',
#  'B506',
#  'B509',
#  'B520',
#  'B519',
#  'B523',
#  'B522',
#  'B507',
#  'B515',
#  'B503',
#  'B505',
#  'B513',
#  'B502',
#  'B508',
#  'B504',
#  'B512',
#  'B501',
#  'B605',
#  'B610',
#  'B611',
#  'B615',
#  'B617',
#  'B614',
#  'B620',
#  'B619',
#  'B608',
#  'B607',
#  'B601',
#  'B609',
#  'B622',
#  'B621',
#  'B604',
#  'B613',
#  'B612',
#  'B618',
#  'B616',
#  'B624',
#  'B602',
#  'B603',
#  'B606',
#  'B623',
#  'B716',
#  'B721',
#  'B704',
#  'B719',
#  'B714',
#  'B723',
#  'B705',
#  'B707',
#  'B715',
#  'B708',
#  'B701',
#  'B720',
#  'B709',
#  'B713',
#  'B712',
#  'B717',
#  'B703',
#  'B711',
#  'B722',
#  'B724',
#  'B718',
#  'B702',
#  'B706',
#  'B710',
#  'B813',
#  'B820',
#  'B823',
#  'B802',
#  'B808',
#  'B806',
#  'B814',
#  'B819',
#  'B822',
#  'B809',
#  'B807',
#  'B810',
#  'B812',
#  'B818',
#  'B815',
#  'B805',
#  'B816',
#  'B804',
#  'B803',
#  'B801',
#  'B811',
#  'B824',
#  'B821',
#  'B817',
#  'B907',
#  'B916',
#  'B905',
#  'B903',
#  'B904',
#  'B921',
#  'B906',
#  'B914',
#  'B901',
#  'B924',
#  'B911',
#  'B913',
#  'B915',
#  'B908',
#  'B912',
#  'B917',
#  'B910',
#  'B920',
#  'B902',
#  'B923',
#  'B918',
#  'B909',
#  'B922',
#  'B919',
#  'C121',
#  'C106',
#  'C112',
#  'C120',
#  'C115',
#  'C107',
#  'C104',
#  'C113',
#  'C101',
#  'C119',
#  'C118',
#  'C102',
#  'C124',
#  'C114',
#  'C105',
#  'C103',
#  'C122',
#  'C111',
#  'C110',
#  'C117',
#  'C109',
#  'C116',
#  'C123',
#  'C108',
#  'C222',
#  'C210',
#  'C211',
#  'C203',
#  'C217',
#  'C208',
#  'C212',
#  'C202',
#  'C218',
#  'C213',
#  'C220',
#  'C215',
#  'C206',
#  'C223',
#  'C209',
#  'C205',
#  'C214',
#  'C204',
#  'C207',
#  'C216',
#  'C219',
#  'C221',
#  'C201',
#  'C224',
#  'C311',
#  'C312',
#  'C306',
#  'C309',
#  'C304',
#  'C301',
#  'C305',
#  'C320',
#  'C318',
#  'C313',
#  'C321',
#  'C310',
#  'C322',
#  'C303',
#  'C323',
#  'C315',
#  'C314',
#  'C308',
#  'C324',
#  'C307',
#  'C302',
#  'C319',
#  'C317',
#  'C316']

# %%
pd.DataFrame(list(chain(*questionnaires)))
# Out:
#         0     1                    2      3
# 0    9521   vgg                  LRP   True
# 1    1073   vgg                 SHAP   True
# 2    9992  alex  IntegratedGradients  False
# 3    5253   vgg     ConfidenceScores  False
# 4    5976   vgg  IntegratedGradients  False
# ..    ...   ...                  ...    ...
# 283  9521   vgg              gradCAM   True
# 284  9710  alex              gradCAM   True
# 285  7798  alex                  LRP  False
# 286  8034  alex                 SHAP   True
# 287  7808  alex     ConfidenceScores  False
#
# [288 rows x 4 columns]

# %%
questionnaires
# Out:
# [[(9521, 'vgg', 'LRP', True),
#   (1073, 'vgg', 'SHAP', True),
#   (9992, 'alex', 'IntegratedGradients', False),
#   (5253, 'vgg', 'ConfidenceScores', False),
#   (5976, 'vgg', 'IntegratedGradients', False),
#   (2187, 'alex', 'ConfidenceScores', True),
#   (329, 'alex', 'LIME', True),
#   (9899, 'alex', 'IntegratedGradients', True),
#   (2136, 'alex', 'LIME', False),
#   (9732, 'vgg', 'SHAP', False),
#   (5789, 'alex', 'LRP', False),
#   (6063, 'alex', 'ConfidenceScores', False),
#   (7489, 'vgg', 'LRP', False),
#   (9663, 'alex', 'SHAP', False),
#   (8917, 'alex', 'SHAP', True),
#   (215, 'vgg', 'ConfidenceScores', True),
#   (9931, 'vgg', 'LIME', True),
#   (7769, 'vgg', 'gradCAM', True),
#   (9710, 'alex', 'LRP', True),
#   (350, 'vgg', 'LIME', False),
#   (995, 'vgg', 'gradCAM', False),
#   (5452, 'alex', 'gradCAM', True),
#   (3898, 'alex', 'gradCAM', False),
#   (7692, 'vgg', 'IntegratedGradients', True)],
#  [(8917, 'alex', 'LIME', True),
#   (3898, 'alex', 'LRP', False),
#   (7152, 'vgg', 'ConfidenceScores', False),
#   (9349, 'alex', 'ConfidenceScores', True),
#   (2136, 'alex', 'ConfidenceScores', False),
#   (5091, 'vgg', 'SHAP', False),
#   (9931, 'vgg', 'ConfidenceScores', True),
#   (5132, 'alex', 'SHAP', False),
#   (3655, 'vgg', 'LIME', False),
#   (7210, 'vgg', 'IntegratedGradients', False),
#   (7769, 'vgg', 'LRP', True),
#   (3921, 'alex', 'LRP', True),
#   (9899, 'vgg', 'gradCAM', True),
#   (1073, 'vgg', 'LIME', True),
#   (9521, 'vgg', 'SHAP', True),
#   (9710, 'alex', 'SHAP', True),
#   (4931, 'alex', 'gradCAM', False),
#   (7692, 'alex', 'gradCAM', True),
#   (1674, 'vgg', 'gradCAM', False),
#   (1315, 'vgg', 'LRP', False),
#   (6063, 'alex', 'IntegratedGradients', False),
#   (215, 'vgg', 'IntegratedGradients', True),
#   (1724, 'alex', 'LIME', False),
#   (9784, 'alex', 'IntegratedGradients', True)],
#  [(3584, 'alex', 'gradCAM', False),
#   (7692, 'alex', 'LRP', True),
#   (9521, 'vgg', 'LIME', True),
#   (9703, 'alex', 'SHAP', True),
#   (1408, 'vgg', 'LRP', False),
#   (6935, 'vgg', 'gradCAM', True),
#   (215, 'alex', 'gradCAM', True),
#   (8917, 'alex', 'ConfidenceScores', True),
#   (9710, 'alex', 'LIME', True),
#   (6063, 'vgg', 'gradCAM', False),
#   (2136, 'alex', 'IntegratedGradients', False),
#   (5186, 'alex', 'IntegratedGradients', True),
#   (4451, 'alex', 'ConfidenceScores', False),
#   (9931, 'vgg', 'IntegratedGradients', True),
#   (1990, 'alex', 'LIME', False),
#   (4584, 'vgg', 'LIME', False),
#   (9360, 'vgg', 'ConfidenceScores', False),
#   (7769, 'vgg', 'SHAP', True),
#   (4780, 'vgg', 'IntegratedGradients', False),
#   (9899, 'vgg', 'LRP', True),
#   (8713, 'alex', 'LRP', False),
#   (3898, 'alex', 'SHAP', False),
#   (1073, 'vgg', 'ConfidenceScores', True),
#   (5705, 'vgg', 'SHAP', False)],
#  [(3898, 'alex', 'LIME', False),
#   (7769, 'vgg', 'LIME', True),
#   (9899, 'vgg', 'SHAP', True),
#   (580, 'vgg', 'gradCAM', False),
#   (9710, 'alex', 'ConfidenceScores', True),
#   (6063, 'vgg', 'LRP', False),
#   (3747, 'vgg', 'ConfidenceScores', False),
#   (4031, 'vgg', 'IntegratedGradients', False),
#   (8406, 'alex', 'gradCAM', False),
#   (3657, 'alex', 'ConfidenceScores', False),
#   (76, 'vgg', 'LRP', True),
#   (9931, 'alex', 'gradCAM', True),
#   (7527, 'alex', 'IntegratedGradients', False),
#   (7692, 'alex', 'SHAP', True),
#   (2136, 'vgg', 'gradCAM', True),
#   (2569, 'alex', 'LIME', True),
#   (215, 'alex', 'LRP', True),
#   (8964, 'vgg', 'LIME', False),
#   (586, 'alex', 'SHAP', False),
#   (9208, 'alex', 'LRP', False),
#   (9521, 'vgg', 'ConfidenceScores', True),
#   (9707, 'vgg', 'SHAP', False),
#   (1073, 'vgg', 'IntegratedGradients', True),
#   (8917, 'alex', 'IntegratedGradients', True)],
#  [(2073, 'vgg', 'SHAP', True),
#   (8662, 'alex', 'SHAP', False),
#   (9899, 'vgg', 'LIME', True),
#   (1073, 'alex', 'gradCAM', False),
#   (3944, 'alex', 'LRP', False),
#   (8301, 'alex', 'ConfidenceScores', True),
#   (3959, 'vgg', 'LRP', False),
#   (217, 'alex', 'gradCAM', True),
#   (215, 'alex', 'SHAP', True),
#   (7769, 'vgg', 'ConfidenceScores', True),
#   (1876, 'vgg', 'LIME', False),
#   (880, 'vgg', 'gradCAM', False),
#   (2021, 'vgg', 'IntegratedGradients', False),
#   (7878, 'vgg', 'ConfidenceScores', False),
#   (8917, 'vgg', 'gradCAM', True),
#   (1995, 'alex', 'LIME', False),
#   (9521, 'vgg', 'IntegratedGradients', True),
#   (3898, 'alex', 'ConfidenceScores', False),
#   (7089, 'alex', 'IntegratedGradients', False),
#   (6063, 'vgg', 'SHAP', False),
#   (2136, 'vgg', 'LRP', True),
#   (7692, 'alex', 'LIME', True),
#   (9931, 'alex', 'LRP', True),
#   (9710, 'alex', 'IntegratedGradients', True)],
#  [(8917, 'vgg', 'LRP', True),
#   (1073, 'alex', 'LRP', False),
#   (9899, 'vgg', 'ConfidenceScores', True),
#   (826, 'vgg', 'LIME', True),
#   (7818, 'alex', 'LIME', False),
#   (8056, 'alex', 'LRP', True),
#   (7988, 'vgg', 'ConfidenceScores', False),
#   (765, 'alex', 'SHAP', False),
#   (2136, 'vgg', 'SHAP', True),
#   (215, 'alex', 'LIME', True),
#   (9931, 'alex', 'SHAP', True),
#   (9710, 'vgg', 'gradCAM', True),
#   (5233, 'vgg', 'IntegratedGradients', False),
#   (8528, 'vgg', 'gradCAM', False),
#   (7769, 'vgg', 'IntegratedGradients', True),
#   (2126, 'alex', 'IntegratedGradients', True),
#   (7692, 'alex', 'ConfidenceScores', True),
#   (910, 'alex', 'ConfidenceScores', False),
#   (4442, 'alex', 'gradCAM', False),
#   (5822, 'vgg', 'SHAP', False),
#   (9521, 'alex', 'gradCAM', True),
#   (3898, 'alex', 'IntegratedGradients', False),
#   (6063, 'vgg', 'LIME', False),
#   (5212, 'vgg', 'LRP', False)],
#  [(5450, 'alex', 'IntegratedGradients', False),
#   (712, 'vgg', 'LRP', False),
#   (1073, 'alex', 'SHAP', False),
#   (6303, 'alex', 'LRP', False),
#   (5037, 'alex', 'LIME', False),
#   (885, 'vgg', 'SHAP', False),
#   (2136, 'vgg', 'LIME', True),
#   (7769, 'alex', 'gradCAM', True),
#   (4389, 'alex', 'SHAP', True),
#   (9899, 'vgg', 'IntegratedGradients', True),
#   (8917, 'vgg', 'SHAP', True),
#   (9389, 'vgg', 'gradCAM', True),
#   (9710, 'vgg', 'LRP', True),
#   (6453, 'alex', 'gradCAM', False),
#   (9521, 'alex', 'LRP', True),
#   (2055, 'vgg', 'ConfidenceScores', True),
#   (9931, 'alex', 'LIME', True),
#   (215, 'alex', 'ConfidenceScores', True),
#   (8971, 'vgg', 'LIME', False),
#   (8224, 'vgg', 'IntegratedGradients', False),
#   (9200, 'alex', 'ConfidenceScores', False),
#   (6063, 'vgg', 'ConfidenceScores', False),
#   (3898, 'vgg', 'gradCAM', False),
#   (7692, 'alex', 'IntegratedGradients', True)],
#  [(6970, 'alex', 'SHAP', False),
#   (467, 'vgg', 'LRP', True),
#   (2050, 'vgg', 'SHAP', False),
#   (9931, 'alex', 'ConfidenceScores', True),
#   (1073, 'alex', 'LIME', False),
#   (9899, 'alex', 'gradCAM', True),
#   (7639, 'alex', 'LIME', True),
#   (7061, 'vgg', 'LIME', False),
#   (7702, 'vgg', 'gradCAM', False),
#   (3898, 'vgg', 'LRP', False),
#   (2136, 'vgg', 'ConfidenceScores', True),
#   (9710, 'vgg', 'SHAP', True),
#   (7769, 'alex', 'LRP', True),
#   (7044, 'alex', 'gradCAM', False),
#   (4066, 'alex', 'IntegratedGradients', False),
#   (6063, 'vgg', 'IntegratedGradients', False),
#   (8885, 'alex', 'LRP', False),
#   (8917, 'vgg', 'LIME', True),
#   (215, 'alex', 'IntegratedGradients', True),
#   (9521, 'alex', 'SHAP', True),
#   (7692, 'vgg', 'gradCAM', True),
#   (8830, 'vgg', 'ConfidenceScores', False),
#   (6210, 'vgg', 'IntegratedGradients', True),
#   (9788, 'alex', 'ConfidenceScores', False)],
#  [(9521, 'alex', 'LIME', True),
#   (738, 'alex', 'SHAP', False),
#   (7692, 'vgg', 'LRP', True),
#   (215, 'vgg', 'gradCAM', True),
#   (9899, 'alex', 'LRP', True),
#   (1482, 'vgg', 'ConfidenceScores', False),
#   (7769, 'alex', 'SHAP', True),
#   (7862, 'alex', 'ConfidenceScores', True),
#   (8917, 'vgg', 'ConfidenceScores', True),
#   (1780, 'vgg', 'LRP', False),
#   (2136, 'vgg', 'IntegratedGradients', True),
#   (9763, 'alex', 'IntegratedGradients', False),
#   (3917, 'alex', 'gradCAM', True),
#   (9931, 'alex', 'IntegratedGradients', True),
#   (1073, 'alex', 'ConfidenceScores', False),
#   (1530, 'alex', 'LIME', False),
#   (3898, 'vgg', 'SHAP', False),
#   (9626, 'vgg', 'LIME', False),
#   (9710, 'vgg', 'LIME', True),
#   (8794, 'vgg', 'IntegratedGradients', False),
#   (6243, 'vgg', 'SHAP', True),
#   (6063, 'alex', 'gradCAM', False),
#   (9372, 'vgg', 'gradCAM', False),
#   (5675, 'alex', 'LRP', False)],
#  [(5833, 'vgg', 'gradCAM', False),
#   (1073, 'alex', 'IntegratedGradients', False),
#   (6063, 'alex', 'LRP', False),
#   (9983, 'vgg', 'LIME', True),
#   (9383, 'alex', 'ConfidenceScores', False),
#   (7769, 'alex', 'LIME', True),
#   (215, 'vgg', 'LRP', True),
#   (9201, 'alex', 'IntegratedGradients', True),
#   (2136, 'alex', 'gradCAM', False),
#   (4211, 'vgg', 'LRP', False),
#   (7550, 'alex', 'gradCAM', True),
#   (9710, 'vgg', 'ConfidenceScores', True),
#   (2608, 'vgg', 'IntegratedGradients', False),
#   (9148, 'alex', 'LIME', False),
#   (9899, 'alex', 'SHAP', True),
#   (9521, 'alex', 'ConfidenceScores', True),
#   (8327, 'vgg', 'ConfidenceScores', False),
#   (9931, 'vgg', 'gradCAM', True),
#   (7692, 'vgg', 'SHAP', True),
#   (2995, 'alex', 'LRP', True),
#   (8917, 'vgg', 'IntegratedGradients', True),
#   (1292, 'alex', 'SHAP', False),
#   (6909, 'vgg', 'SHAP', False),
#   (3898, 'vgg', 'LIME', False)],
#  [(7995, 'vgg', 'SHAP', False),
#   (1073, 'vgg', 'gradCAM', True),
#   (9521, 'alex', 'IntegratedGradients', True),
#   (9899, 'alex', 'LIME', True),
#   (3106, 'vgg', 'ConfidenceScores', True),
#   (9710, 'vgg', 'IntegratedGradients', True),
#   (7769, 'alex', 'ConfidenceScores', True),
#   (3898, 'vgg', 'ConfidenceScores', False),
#   (2451, 'alex', 'IntegratedGradients', False),
#   (2495, 'alex', 'LRP', True),
#   (9753, 'vgg', 'LRP', False),
#   (8054, 'alex', 'SHAP', True),
#   (9931, 'vgg', 'LRP', True),
#   (9509, 'vgg', 'gradCAM', False),
#   (7692, 'vgg', 'LIME', True),
#   (8917, 'alex', 'gradCAM', True),
#   (1602, 'alex', 'gradCAM', False),
#   (2136, 'alex', 'LRP', False),
#   (6063, 'alex', 'SHAP', False),
#   (9777, 'alex', 'LIME', False),
#   (3873, 'alex', 'ConfidenceScores', False),
#   (5123, 'vgg', 'IntegratedGradients', False),
#   (215, 'vgg', 'SHAP', True),
#   (3988, 'vgg', 'LIME', False)],
#  [(7769, 'alex', 'IntegratedGradients', True),
#   (6063, 'alex', 'LIME', False),
#   (8917, 'alex', 'LRP', True),
#   (1073, 'vgg', 'LRP', True),
#   (2136, 'alex', 'SHAP', False),
#   (215, 'vgg', 'LIME', True),
#   (3898, 'vgg', 'IntegratedGradients', False),
#   (1159, 'vgg', 'LIME', False),
#   (6675, 'vgg', 'IntegratedGradients', True),
#   (8052, 'alex', 'IntegratedGradients', False),
#   (4248, 'vgg', 'LRP', False),
#   (7692, 'vgg', 'ConfidenceScores', True),
#   (4323, 'vgg', 'ConfidenceScores', False),
#   (9899, 'alex', 'ConfidenceScores', True),
#   (4266, 'vgg', 'SHAP', False),
#   (8002, 'alex', 'LIME', True),
#   (6979, 'alex', 'gradCAM', False),
#   (9931, 'vgg', 'SHAP', True),
#   (753, 'vgg', 'gradCAM', False),
#   (9521, 'vgg', 'gradCAM', True),
#   (9710, 'alex', 'gradCAM', True),
#   (7798, 'alex', 'LRP', False),
#   (8034, 'alex', 'SHAP', True),
#   (7808, 'alex', 'ConfidenceScores', False)]]

# %%
np.squeeze(codes_list)
# Out:
# array([['B108', 'B111', 'B118', 'B123', 'B124', 'B115', 'B113', 'B104',
#         'B110', 'B122', 'B117', 'B112', 'B121', 'B114', 'B103', 'B105',
#         'B109', 'B106', 'B101', 'B120', 'B119', 'B116', 'B102', 'B107'],
#        ['B210', 'B206', 'B221', 'B217', 'B212', 'B218', 'B203', 'B213',
#         'B219', 'B223', 'B208', 'B220', 'B207', 'B209', 'B205', 'B204',
#         'B215', 'B201', 'B222', 'B224', 'B202', 'B211', 'B216', 'B214'],
#        ['B313', 'B310', 'B309', 'B320', 'B319', 'B321', 'B303', 'B301',
#         'B302', 'B312', 'B306', 'B317', 'B314', 'B304', 'B315', 'B318',
#         'B324', 'B308', 'B323', 'B307', 'B316', 'B311', 'B305', 'B322'],
#        ['B411', 'B404', 'B406', 'B424', 'B412', 'B402', 'B421', 'B423',
#         'B416', 'B418', 'B415', 'B407', 'B419', 'B403', 'B408', 'B414',
#         'B401', 'B420', 'B413', 'B417', 'B409', 'B422', 'B405', 'B410'],
#        ['B521', 'B518', 'B511', 'B510', 'B517', 'B516', 'B524', 'B514',
#         'B506', 'B509', 'B520', 'B519', 'B523', 'B522', 'B507', 'B515',
#         'B503', 'B505', 'B513', 'B502', 'B508', 'B504', 'B512', 'B501'],
#        ['B605', 'B610', 'B611', 'B615', 'B617', 'B614', 'B620', 'B619',
#         'B608', 'B607', 'B601', 'B609', 'B622', 'B621', 'B604', 'B613',
#         'B612', 'B618', 'B616', 'B624', 'B602', 'B603', 'B606', 'B623'],
#        ['B716', 'B721', 'B704', 'B719', 'B714', 'B723', 'B705', 'B707',
#         'B715', 'B708', 'B701', 'B720', 'B709', 'B713', 'B712', 'B717',
#         'B703', 'B711', 'B722', 'B724', 'B718', 'B702', 'B706', 'B710'],
#        ['B813', 'B820', 'B823', 'B802', 'B808', 'B806', 'B814', 'B819',
#         'B822', 'B809', 'B807', 'B810', 'B812', 'B818', 'B815', 'B805',
#         'B816', 'B804', 'B803', 'B801', 'B811', 'B824', 'B821', 'B817'],
#        ['B907', 'B916', 'B905', 'B903', 'B904', 'B921', 'B906', 'B914',
#         'B901', 'B924', 'B911', 'B913', 'B915', 'B908', 'B912', 'B917',
#         'B910', 'B920', 'B902', 'B923', 'B918', 'B909', 'B922', 'B919'],
#        ['C121', 'C106', 'C112', 'C120', 'C115', 'C107', 'C104', 'C113',
#         'C101', 'C119', 'C118', 'C102', 'C124', 'C114', 'C105', 'C103',
#         'C122', 'C111', 'C110', 'C117', 'C109', 'C116', 'C123', 'C108'],
#        ['C222', 'C210', 'C211', 'C203', 'C217', 'C208', 'C212', 'C202',
#         'C218', 'C213', 'C220', 'C215', 'C206', 'C223', 'C209', 'C205',
#         'C214', 'C204', 'C207', 'C216', 'C219', 'C221', 'C201', 'C224'],
#        ['C311', 'C312', 'C306', 'C309', 'C304', 'C301', 'C305', 'C320',
#         'C318', 'C313', 'C321', 'C310', 'C322', 'C303', 'C323', 'C315',
#         'C314', 'C308', 'C324', 'C307', 'C302', 'C319', 'C317', 'C316']],
#       dtype='<U4')

# %%
df.groupby(by=)
# Out:
#                B108           B111              B118        B123        B124  \
# 0    q8custardapple  q11Bostonbull  q18toilet tissue  q23gaspump  q24mailbag
# 1               NaN            NaN               NaN         NaN         NaN
# 2               NaN            NaN               NaN         NaN         NaN
# 3               NaN            NaN               NaN         NaN         NaN
# 4               NaN            NaN               NaN         NaN         NaN
# ..              ...            ...               ...         ...         ...
# 117             NaN            NaN               NaN         NaN         NaN
# 118             NaN            NaN               NaN         NaN         NaN
# 119             NaN            NaN               NaN         NaN         NaN
# 120             NaN            NaN               NaN         NaN         NaN
# 121             NaN            NaN               NaN         NaN         NaN
#
#                        B115           B113     B104       B110         B122  \
# 0    q15American black bear  q13whitestork  q4goose  q10jaguar  q22lakeside
# 1                       NaN            NaN      NaN        NaN          NaN
# 2                       NaN            NaN      NaN        NaN          NaN
# 3                       NaN            NaN      NaN        NaN          NaN
# 4                       NaN            NaN      NaN        NaN          NaN
# ..                      ...            ...      ...        ...          ...
# 117                     NaN            NaN      NaN        NaN          NaN
# 118                     NaN            NaN      NaN        NaN          NaN
# 119                     NaN            NaN      NaN        NaN          NaN
# 120                     NaN            NaN      NaN        NaN          NaN
# 121                     NaN            NaN      NaN        NaN          NaN
#
#      ...          B103                 B105         B109         B106  \
# 0    ...  q3watertower  q5chamberednautilus  q9gyromitra  q6sliderule
# 1    ...           NaN                  NaN          NaN          NaN
# 2    ...           NaN                  NaN          NaN          NaN
# 3    ...           NaN                  NaN          NaN          NaN
# 4    ...           NaN                  NaN          NaN          NaN
# ..   ...           ...                  ...          ...          ...
# 117  ...           NaN                  NaN          NaN          NaN
# 118  ...           NaN                  NaN          NaN          NaN
# 119  ...           NaN                  NaN          NaN          NaN
# 120  ...           NaN                  NaN          NaN          NaN
# 121  ...           NaN                  NaN          NaN          NaN
#
#         B101      B120                      B119           B116         B102  \
# 0    q1coral  q20junco  q19wire-hairedfoxterrier  q16vine snake  q2boathouse
# 1        NaN       NaN                       NaN            NaN          NaN
# 2        NaN       NaN                       NaN            NaN          NaN
# 3        NaN       NaN                       NaN            NaN          NaN
# 4        NaN       NaN                       NaN            NaN          NaN
# ..       ...       ...                       ...            ...          ...
# 117      NaN       NaN                       NaN            NaN          NaN
# 118      NaN       NaN                       NaN            NaN          NaN
# 119      NaN       NaN                       NaN            NaN          NaN
# 120      NaN       NaN                       NaN            NaN          NaN
# 121      NaN       NaN                       NaN            NaN          NaN
#
#                B107
# 0    q7shoppingcart
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ..              ...
# 117             NaN
# 118             NaN
# 119             NaN
# 120             NaN
# 121             NaN
#
# [122 rows x 24 columns]

# %%
df.drop(0).groupby(by="QUESTNNR").dropnan()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/30/yd__z7kj1w11s9x68_l70ysr0000gn/T/ipykernel_28181/3323832801.py in <module>
# ----> 1 df.drop(0).groupby(by="QUESTNNR").dropnan()
#
# ~/opt/anaconda3/envs/xai_env/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     910
#     911         raise AttributeError(
# --> 912             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     913         )
#     914
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'dropnan'
